# %%
import tensorflow as tf
import tensorflow.keras as keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import signal
from tqdm import tqdm
from numpy.fft import fft, fftshift
import matplotlib.pyplot as plt
import seaborn as sns
import random
from tqdm import tqdm
import optuna
from scipy.integrate import cumtrapz
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import optimizers
import tensorflow_addons as tfa
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Bidirectional,Dropout
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from sklearn.model_selection import KFold,StratifiedKFold
from numpy.random import seed
from tensorflow.keras.layers import Activation, Conv2D, MaxPooling2D, Flatten, GlobalAveragePooling1D
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from statistics import mean, stdev
import warnings
warnings.filterwarnings(action='ignore')

print(tf.__version__)
# Out:
# 2.5.0

# %% [markdown]
# #### Data loading

# %%
train=pd.read_csv('./train_features.csv')
train_labels=pd.read_csv('./train_labels.csv')
test=pd.read_csv('./test_features.csv')

submission=pd.read_csv('./sample_submission.csv')

pd.options.display.max_columns=50

# %%
train.shape
# Out:
# (1875000, 8)

# %% [markdown]
# #### Feature engneering

# %% [markdown]
# #####  가속도, 자이로, (자이로-가속도) 센서값을 에너지로 표현

# %%
train['acc_Energy']=(train['acc_x']**2+train['acc_y']**2+train['acc_z']**2)**(1/3)
test['acc_Energy']=(test['acc_x']**2+test['acc_y']**2+test['acc_z']**2)**(1/3)

train['gy_Energy']=(train['gy_x']**2+train['gy_y']**2+train['gy_z']**2)**(1/3)
test['gy_Energy']=(test['gy_x']**2+test['gy_y']**2+test['gy_z']**2)**(1/3)

train['gy_acc_Energy']=((train['gy_x']-train['acc_x'])**2+(train['gy_y']-train['acc_y'])**2+(train['gy_z']-train['acc_z'])**2)**(1/3)
test['gy_acc_Energy']=((test['gy_x']-test['acc_x'])**2+(test['gy_y']-test['acc_y'])**2+(test['gy_z']-test['acc_z'])**2)**(1/3)

# %%
train.shape
# Out:
# (1875000, 11)

# %% [markdown]
# ###### id별 데이터는 0.02초마다 측정된 값들이기 때문에 이전 시간 대비 변화량 적용

# %%
# dt=0.02 
# def jerk_signal(signal): 
#         return np.array([(signal[i+1]-signal[i])/dt for i in range(len(signal)-1)])

# %%
# train_dt=[]
# for i in tqdm(train['id'].unique()):
#     temp=train.loc[train['id']==i]
#     for v in train.columns[2:]:
#         values=jerk_signal(temp[v].values)
#         values=np.insert(values,0,0)
#         temp.loc[:,v+'_dt']=values
#     train_dt.append(temp)
# Out:
# 100%|██████████| 3125/3125 [00:47<00:00, 65.73it/s]

# %%
# test_dt=[]
# for i in tqdm(test['id'].unique()):
#     temp=test.loc[test['id']==i]
#     for v in train.columns[2:]:
#         values=jerk_signal(temp[v].values)
#         values=np.insert(values,0,0)
#         temp.loc[:,v+'_dt']=values
#     test_dt.append(temp)
# Out:
# 100%|██████████| 782/782 [00:10<00:00, 74.85it/s]

# %% [markdown]
# ## 푸리에 변환

# %%
# from scipy import fftpack
# from numpy.fft import *

# def fourier_transform_one_signal(t_signal):
#     complex_f_signal= fftpack.fft(t_signal)
#     amplitude_f_signal=np.abs(complex_f_signal)
#     return amplitude_f_signal

# %%
# 1874998      -0.260074     -0.089713          0.057150     -0.390820
# 1874999      -0.513215      0.943240          1.102985     -0.768244
#
# [1875000 rows x 22 columns]

# %%
# fft=[]
# for i in tqdm(train['id'].unique()):
#     temp=train.loc[train['id']==i]
#     for i in train.columns[2:8]:
#         temp[i]=fourier_transform_one_signal(temp[i].values)
#     fft.append(temp)
# train=pd.concat(fft)
# Out:
# 100%|██████████| 3125/3125 [00:11<00:00, 266.41it/s]

# %%
# test=pd.concat(test_dt)
# test
# Out:
#           id  time     acc_x     acc_y     acc_z       gy_x       gy_y  \
# 0       3125     0 -0.628100 -0.160155  0.151487  49.665357  88.435961
# 1       3125     1 -0.462548  0.012462 -0.053726  56.953059  96.185341
# 2       3125     2 -0.363481 -0.091789 -0.130004  29.557396  93.836453
# 3       3125     3 -0.351750 -0.239870 -0.193053  23.686172  88.608721
# 4       3125     4 -0.312934 -0.123762 -0.318621  20.410071  85.327707
# ...      ...   ...       ...       ...       ...        ...        ...
# 469195  3906   595  0.104191 -0.784979  0.639513 -10.475346  14.095361
# 469196  3906   596  0.103297 -0.758954  0.615687 -25.360272  -8.523018
# 469197  3906   597  0.128294 -0.749389  0.586184 -27.917723 -23.186245
# 469198  3906   598  0.104130 -0.692731  0.573397 -27.847980 -30.407555
# 469199  3906   599  0.059299 -0.613487  0.556780 -29.900725 -36.586219
#
#               gy_z  acc_Energy  gy_Energy  gy_acc_Energy  acc_total  acc_x_dt  \
# 0        13.597668    0.762377  21.878437      21.938882   0.665663  0.000000
# 1        16.278458    0.600917  23.367908      23.399763   0.465824  8.277606
# 2        13.329043    0.539978  21.440856      21.471510   0.396793  4.953330
# 3        13.449771    0.602338  20.482783      20.533967   0.467477  0.586560
# 4        13.884912    0.598853  19.908061      19.944125   0.463426  1.940804
# ...            ...         ...        ...            ...        ...       ...
# 469195 -190.358982    1.011867  33.185050      33.266220   1.017853 -3.361947
# 469196 -180.393291    0.988451  32.158563      32.227841   0.982726 -0.044724
# 469197 -162.624160    0.973171  30.280197      30.339698   0.960028  1.249868
# 469198 -138.761676    0.935801  27.569491      27.623600   0.905265 -1.208173
# 469199 -116.423810    0.883607  25.086160      25.133208   0.830594 -2.241562
#
#         acc_y_dt   acc_z_dt      gy_x_dt      gy_y_dt      gy_z_dt  \
# 0       0.000000   0.000000     0.000000     0.000000     0.000000
# 1       8.630860 -10.260605   364.385137   387.469010   134.039504
# 2      -5.212527  -3.813919 -1369.783175  -117.444408  -147.470749
# 3      -7.404041  -3.152460  -293.561181  -261.386607     6.036401
# 4       5.805371  -6.278395  -163.805080  -164.050703    21.757050
# ...          ...        ...          ...          ...          ...
# 469195  3.580749   0.006738  -771.499131  -849.527466    -8.671145
# 469196  1.301266  -1.191327  -744.246300 -1130.918984   498.284561
# 469197  0.478247  -1.475149  -127.872573  -733.161359   888.456533
# 469198  2.832870  -0.639335     3.487160  -361.065463  1193.124196
# 469199  3.962233  -0.830861  -102.637249  -308.933221  1116.893337
#
#         acc_Energy_dt  gy_Energy_dt  gy_acc_Energy_dt  acc_total_dt
# 0            0.000000      0.000000          0.000000      0.000000
# 1           -8.072977     74.473561         73.044041     -9.991947
# 2           -3.046963    -96.352572        -96.412634     -3.451554
# 3            3.118006    -47.903682        -46.877152      3.534209
# 4           -0.174231    -28.736096        -29.492133     -0.202539
# ...               ...           ...               ...           ...
# 469195      -2.122263     -9.277974         -9.636798     -3.235578
# 469196      -1.170808    -51.324317        -51.918937     -1.756341
# 469197      -0.763970    -93.918343        -94.407192     -1.134905
# 469198      -1.868499   -135.535264       -135.804895     -2.738180
# 469199      -2.609723   -124.166545       -124.519564     -3.733540
#
# [469200 rows x 22 columns]

# %% [markdown]
# ## 데이터셋 나누기

# %%
acc=train[["acc_x","acc_y","acc_z"]]
gy=train[["gy_x","gy_y","gy_z"]]

# %%
acto=train["acc_total"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/envs/py38_tensorflow/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'acc_total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-dddd18d35973> in <module>
# ----> 1 acto=train["acc_total"]
#
# /anaconda/envs/py38_tensorflow/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /anaconda/envs/py38_tensorflow/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'acc_total'

# %% [markdown]
# ## 스케일링 진행

# %%
train["acc_x_norm"]=(train["acc_x"]-np.nanmean(acc))/np.nanstd(acc)
train["acc_y_norm"]=(train["acc_y"]-np.nanmean(acc))/np.nanstd(acc)
train["acc_z_norm"]=(train["acc_z"]-np.nanmean(acc))/np.nanstd(acc)

train["gy_x_norm"]=(train["gy_x"]-np.nanmean(gy))/np.nanstd(gy)
train["gy_y_norm"]=(train["gy_y"]-np.nanmean(gy))/np.nanstd(gy)
train["gy_z_norm"]=(train["gy_z"]-np.nanmean(gy))/np.nanstd(gy)

train["acc_total_norm"]=(train["acc_total"]-mean(acto))/stdev(acto)

# %%
test["acc_x_norm"]=(test["acc_x"]-np.nanmean(acc))/np.nanstd(acc)
test["acc_y_norm"]=(test["acc_y"]-np.nanmean(acc))/np.nanstd(acc)
test["acc_z_norm"]=(test["acc_z"]-np.nanmean(acc))/np.nanstd(acc)

test["gy_x_norm"]=(test["gy_x"]-np.nanmean(gy))/np.nanstd(gy)
test["gy_y_norm"]=(test["gy_y"]-np.nanmean(gy))/np.nanstd(gy)
test["gy_z_norm"]=(test["gy_z"]-np.nanmean(gy))/np.nanstd(gy)

test["acc_total_norm"]=(test["acc_total"]-mean(acto))/stdev(acto)

# %%
train=train.drop(columns=["acc_x", "acc_y", "acc_z",
                   "gy_x", "gy_y", "gy_z", "acc_total"])

# %%
test=test.drop(columns=["acc_x", "acc_y", "acc_z",
                   "gy_x", "gy_y", "gy_z", "acc_total"])

# %%
train
# Out:
#            id  time  acc_Energy  gy_Energy  gy_acc_Energy  acc_x_dt  acc_y_dt  \
# 0           0     0    1.146962  12.465436      12.427938  0.000000  0.000000
# 1           0     1    1.200703  12.913284      12.865692  4.080495 -0.980114
# 2           0     2    1.217403  13.725729      13.692643  0.845632  0.192961
# 3           0     3    1.209981  15.374021      15.314907 -0.575711 -1.762585
# 4           0     4    1.211254  16.074363      16.017964  0.389598  2.130453
# ...       ...   ...         ...        ...            ...       ...       ...
# 1874995  3124   595    1.009050  25.963234      25.897316  1.484646  0.303666
# 1874996  3124   596    1.002827  25.784692      25.722482  1.474659 -0.005442
# 1874997  3124   597    1.006239  25.628060      25.572145  0.915321 -0.407957
# 1874998  3124   598    1.001038  25.626266      25.573288  1.709833 -0.796984
# 1874999  3124   599    0.990773  25.645131      25.595348  2.609116 -0.883512
#
#          acc_z_dt     gy_x_dt     gy_y_dt     gy_z_dt  acc_Energy_dt  \
# 0        0.000000    0.000000    0.000000    0.000000       0.000000
# 1       -1.699854   44.735403 -429.504677  337.444793       2.687024
# 2       -3.546937 -196.018888 -249.173073   -4.620631       0.835012
# 3        1.908626  316.513181 -473.763910 -121.719195      -0.371100
# 4       -0.365665   78.686055 -215.435892  -25.361098       0.063656
# ...           ...         ...         ...         ...            ...
# 1874995  0.800069 -150.644663  -34.630282   -8.380088      -0.679712
# 1874996  1.775771  -39.061611  110.842743  -16.732496      -0.311171
# 1874997  1.744566  113.799702  151.036858 -137.001896       0.170620
# 1874998  0.479107  211.827245  -18.171144  -44.717652      -0.260074
# 1874999  0.534668  285.946217  -52.118894  -20.837588      -0.513215
#
#          gy_Energy_dt  gy_acc_Energy_dt  acc_total_dt  acc_x_norm  acc_y_norm  \
# 0            0.000000          0.000000      0.000000   35.157001    8.070030
# 1           22.392358         21.887693      4.366731   -0.026623    0.762217
# 2           40.622253         41.347563      1.377227    0.074664    0.287896
# 3           82.414636         81.113199     -0.613248    0.128041    0.106169
# 4           35.017060         35.152822      0.105059    0.238228    0.273993
# ...               ...               ...           ...         ...         ...
# 1874995      8.387109          8.432977     -1.027613    0.512342    0.009042
# 1874996     -8.927089         -8.741727     -0.468141   13.162699    5.017913
# 1874997     -7.831611         -7.516832      0.256510    0.539681    0.161281
# 1874998     -0.089713          0.057150     -0.390820    0.979279    0.011225
# 1874999      0.943240          1.102985     -0.768244    1.181284    0.067659
#
#          acc_z_norm  gy_x_norm  gy_y_norm  gy_z_norm  acc_total_norm
# 0         13.843797   0.370858   0.934146   0.113324        0.386070
# 1          0.543080  -0.193071  -0.104920  -0.032555        0.606253
# 2          0.015684  -0.107874  -0.061778  -0.048252        0.675697
# 3         -0.071316  -0.118409   0.162515  -0.038695        0.644775
# 4          0.184501  -0.251760   0.529773   0.117445        0.650073
# ...             ...        ...        ...        ...             ...
# 1874995    0.561119   0.117476   0.374209   0.073341       -0.155342
# 1874996    5.266125   3.132881  17.836302  12.370927       -0.178947
# 1874997   -0.099364  -0.116360  -0.040538  -0.283232       -0.166013
# 1874998    0.208044   0.164914   1.379396   0.378667       -0.185719
# 1874999    0.747911  -0.107599   0.960949   0.282085       -0.224456
#
# [1875000 rows x 22 columns]

# %% [markdown]
# ### Standard scaling 적용

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
col=train.columns
scaler = StandardScaler()

train.iloc[:,2:]= scaler.fit_transform(train.iloc[:,2:])
train = pd.DataFrame(data = train,columns =col)

test.iloc[:,2:]= scaler.transform(test.iloc[:,2:])
test = pd.DataFrame(data = test,columns =col)

# %%
train
# Out:
#            id  time  acc_Energy  gy_Energy  gy_acc_Energy  acc_x_dt  acc_y_dt  \
# 0           0     0    0.495681  -0.272719      -0.276391  0.000027  0.000298
# 1           0     1    0.742974  -0.236152      -0.240632  0.416836 -0.118821
X=np.array(train.iloc[:,2:]).reshape(3125, 600, -1)

# %%
X.shape
# Out:
# (3125, 600, 20)

# %%
test_x=np.array(test.iloc[:,2:]).reshape(782, 600, -1)
test_x.shape

y = train_labels['label'].values
y = tf.keras.utils.to_categorical(train_labels['label']) 
y.shape
# Out:
# (3125, 61)

# %% [markdown]
# ##### 모델링
#
# + CNN, LSTM, CNN+LSTM 등 여러 구조 적용해보다가 CNN에서 Flatten 없이 Global average pooling 한 구조가 가장 성능이 좋아 채택했습니다.

# %% [markdown]
# ##### 모델 구조

# %%
from sklearn.model_selection import KFold

# %%
prediction=0
folds=5
repeats=5
epochsize=40
drop=0.5
kfold = KFold(n_splits=folds, shuffle=True)

for k in range(repeats):
    for train_ind, test_ind in kfold.split(X, y):
        seed(2021)
        tf.random.set_seed(2021)

        input_layer = keras.layers.Input(X.shape[1:])
        conv1 = keras.layers.Conv1D(filters=128, kernel_size=9, padding='same')(input_layer)
        conv1 = keras.layers.BatchNormalization()(conv1)
        conv1 = keras.layers.Activation(activation='relu')(conv1)
        conv1 = keras.layers.Dropout(rate=0.3)(conv1)

        conv2 = keras.layers.Conv1D(filters=256, kernel_size=6, padding='same')(conv1)
        conv2 = keras.layers.BatchNormalization()(conv2)
        conv2 = keras.layers.Activation('relu')(conv2)
        conv2 = keras.layers.Dropout(rate=0.4)(conv2)

        conv3 = keras.layers.Conv1D(128, kernel_size=3,padding='same')(conv2)
        conv3 = keras.layers.BatchNormalization()(conv3)
        conv3 = keras.layers.Activation('relu')(conv3)
        conv3 = keras.layers.Dropout(rate=0.5)(conv3)

        gap = keras.layers.GlobalAveragePooling1D()(conv3)

        output_layer = keras.layers.Dense(61, activation='softmax')(gap)

        model = keras.models.Model(inputs=input_layer, outputs=output_layer)

        #adam = optimizers.Adam(lr=0.0001)

        model.compile(loss='categorical_crossentropy',
                      optimizer='Adam',
                      metrics=['accuracy'])

        model.fit(np.array(X)[train_ind], y[train_ind], epochs=epochsize, batch_size=64,
                  validation_data=(np.array(X)[test_ind], y[test_ind]))

        prediction += (model.predict(test_x)/(folds*repeats))
    print(f'\n\n********    {k+1}번 러닝 완료    *********\n\n')

submission.iloc[:,1:]=prediction
submission.to_csv('py_answer1.csv', index=False)
# Out:
# Epoch 1/40
# 40/40 [==============================] - 7s 97ms/step - loss: 2.8836 - accuracy: 0.4472 - val_loss: 3.7165 - val_accuracy: 0.1552
# Epoch 2/40
# 40/40 [==============================] - 3s 81ms/step - loss: 1.9837 - accuracy: 0.5512 - val_loss: 2.2494 - val_accuracy: 0.5328
# Epoch 3/40
# 40/40 [==============================] - 3s 81ms/step - loss: 1.7327 - accuracy: 0.5768 - val_loss: 1.9470 - val_accuracy: 0.5232
# Epoch 4/40
# 40/40 [==============================] - 3s 79ms/step - loss: 1.5723 - accuracy: 0.6048 - val_loss: 1.6755 - val_accuracy: 0.5904
# Epoch 5/40
# 40/40 [==============================] - 3s 80ms/step - loss: 1.4364 - accuracy: 0.6336 - val_loss: 1.7476 - val_accuracy: 0.5904
# Epoch 6/40
# Epoch 3/40
# 40/40 [==============================] - 3s 78ms/step - loss: 1.7262 - accuracy: 0.5848 - val_loss: 1.9423 - val_accuracy: 0.5488
# Epoch 4/40
# 40/40 [==============================] - 3s 80ms/step - loss: 1.5743 - accuracy: 0.6144 - val_loss: 1.7587 - val_accuracy: 0.5680
# Epoch 5/40
# 40/40 [==============================] - 3s 81ms/step - loss: 1.4255 - accuracy: 0.6332 - val_loss: 1.6326 - val_accuracy: 0.5888
# Epoch 6/40
# 40/40 [==============================] - 3s 81ms/step - loss: 1.3345 - accuracy: 0.6528 - val_loss: 1.7360 - val_accuracy: 0.6080
# Epoch 7/40
# 40/40 [==============================] - 3s 78ms/step - loss: 1.2196 - accuracy: 0.6732 - val_loss: 1.4760 - val_accuracy: 0.6160
# Epoch 8/40
# 40/40 [==============================] - 3s 79ms/step - loss: 1.1540 - accuracy: 0.6892 - val_loss: 1.3779 - val_accuracy: 0.6496
# Epoch 9/40
# 40/40 [==============================] - 3s 80ms/step - loss: 1.0966 - accuracy: 0.7076 - val_loss: 1.1727 - val_accuracy: 0.6912
# Epoch 10/40
# 40/40 [==============================] - 3s 78ms/step - loss: 1.0044 - accuracy: 0.7224 - val_loss: 1.2060 - val_accuracy: 0.6768
# Epoch 11/40
# 40/40 [==============================] - 3s 79ms/step - loss: 1.0032 - accuracy: 0.7244 - val_loss: 1.1042 - val_accuracy: 0.6896
# Epoch 12/40
# 40/40 [==============================] - 3s 81ms/step - loss: 0.8957 - accuracy: 0.7524 - val_loss: 1.0918 - val_accuracy: 0.6912
# Epoch 13/40
# 40/40 [==============================] - 3s 81ms/step - loss: 0.8753 - accuracy: 0.7600 - val_loss: 0.9839 - val_accuracy: 0.7136
# Epoch 14/40
# 40/40 [==============================] - 3s 77ms/step - loss: 0.8116 - accuracy: 0.7772 - val_loss: 1.0389 - val_accuracy: 0.7008
# Epoch 15/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.7852 - accuracy: 0.7720 - val_loss: 0.9509 - val_accuracy: 0.7248
# Epoch 16/40
# 40/40 [==============================] - 3s 80ms/step - loss: 0.7611 - accuracy: 0.7896 - val_loss: 0.9747 - val_accuracy: 0.7168
# Epoch 17/40
# 40/40 [==============================] - 3s 84ms/step - loss: 0.7478 - accuracy: 0.7880 - val_loss: 0.8797 - val_accuracy: 0.7440
# Epoch 18/40
# 40/40 [==============================] - 3s 78ms/step - loss: 0.7115 - accuracy: 0.7920 - val_loss: 0.8574 - val_accuracy: 0.7760
# Epoch 19/40
# ...
# Epoch 9/40
# 40/40 [==============================] - 3s 80ms/step - loss: 1.0813 - accuracy: 0.7028 - val_loss: 1.1738 - val_accuracy: 0.6640
# Epoch 10/40
# 40/40 [==============================] - 3s 82ms/step - loss: 0.9977 - accuracy: 0.7336 - val_loss: 1.1123 - val_accuracy: 0.6752
# Epoch 11/40
# 40/40 [==============================] - 3s 78ms/step - loss: 0.9414 - accuracy: 0.7396 - val_loss: 1.1547 - val_accuracy: 0.6832
# Epoch 12/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.9622 - accuracy: 0.7364 - val_loss: 1.0090 - val_accuracy: 0.7008
# Epoch 13/40
# 40/40 [==============================] - 3s 81ms/step - loss: 0.8509 - accuracy: 0.7592 - val_loss: 0.9517 - val_accuracy: 0.7392
# Epoch 14/40
# 40/40 [==============================] - 3s 82ms/step - loss: 0.8269 - accuracy: 0.7624 - val_loss: 0.9954 - val_accuracy: 0.7248
# Epoch 15/40
# 40/40 [==============================] - 3s 78ms/step - loss: 0.8414 - accuracy: 0.7632 - val_loss: 1.1167 - val_accuracy: 0.6944
# Epoch 16/40
# 40/40 [==============================] - 3s 80ms/step - loss: 0
40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.7376 - accuracy: 0.7880 - val_loss: 0.8975 - val_accuracy: 0.7360
# Epoch 17/40
# 40/40 [==============================] - 3s 80ms/step - loss: 0.7268 - accuracy: 0.7860 - val_loss: 0.8405 - val_accuracy: 0.7648
# Epoch 18/40
# 40/40 [==============================] - 3s 78ms/step - loss: 0.6620 - accuracy: 0.8076 - val_loss: 0.7930 - val_accuracy: 0.7632
# Epoch 19/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.6381 - accuracy: 0.8180 - val_loss: 0.7826 - val_accuracy: 0.7744
# Epoch 20/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.6090 - accuracy: 0.8260 - val_loss: 0.8274 - val_accuracy: 0.7696
# Epoch 21/40
# 40/40 [==============================] - 3s 78ms/step - loss: 0.5854 - accuracy: 0.8268 - val_loss: 0.8071 - val_accuracy: 0.7776
# Epoch 22/40
# 40/40 [==============================] - 3s 78ms/step - loss: 0.6127 - accuracy: 0.8272 - val_loss: 0.7629 - val_accuracy: 0.7936
# Epoch 23/40
# 40/40 [==============================] - 3s 81ms/step - loss: 0.5816 - accuracy: 0.8312 - val_loss: 0.7279 - val_accuracy: 0.7968
# Epoch 24/40
# 40/40 [==============================] - 3s 77ms/step - loss: 0.5632 - accuracy: 0.8404 - val_loss: 0.7004 - val_accuracy: 0.8016
# Epoch 25/40
# 40/40 [==============================] - 3s 80ms/step - loss: 0.5370 - accuracy: 0.8424 - val_loss: 0.7004 - val_accuracy: 0.7984
# Epoch 26/40
# 40/40 [==============================] - 3s 80ms/step - loss: 0.5224 - accuracy: 0.8388 - val_loss: 0.6572 - val_accuracy: 0.7920
# Epoch 27/40
# 40/40 [==============================] - 3s 81ms/step - loss: 0.4876 - accuracy: 0.8632 - val_loss: 0.7325 - val_accuracy: 0.7792
# Epoch 28/40
# 40/40 [==============================] - 3s 77ms/step - loss: 0.5359 - accuracy: 0.8404 - val_loss: 0.7293 - val_accuracy: 0.7888
# Epoch 29/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4845 - accuracy: 0.8552 - val_loss: 0.6601 - val_accuracy: 0.8080
# Epoch 30/40
# 40/40 [==============================] - 3s 82ms/step - loss: 0.4394 - accuracy: 0.8760 - val_loss: 0.6465 - val_accuracy: 0.8032
# Epoch 31/40
# 40/40 [==============================] - 3s 82ms/step - loss: 0.4426 - accuracy: 0.8684 - val_loss: 0.7120 - val_accuracy: 0.7888
# Epoch 32/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4394 - accuracy: 0.8692 - val_loss: 0.6085 - val_accuracy: 0.8032
# Epoch 33/40
# 40/40 [==============================] - 3s 80ms/step - loss: 0.4209 - accuracy: 0.8708 - val_loss: 0.6697 - val_accuracy: 0.7808
# Epoch 34/40
# 40/40 [==============================] - 3s 82ms/step - loss: 0.4360 - accuracy: 0.8636 - val_loss: 0.6885 - val_accuracy: 0.7872
# Epoch 35/40
# 40/40 [==============================] - 3s 83ms/step - loss: 0.4597 - accuracy: 0.8668 - val_loss: 0.6426 - val_accuracy: 0.8064
# Epoch 36/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4067 - accuracy: 0.8784 - val_loss: 0.6423 - val_accuracy: 0.8192
# Epoch 37/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4179 - accuracy: 0.8740 - val_loss: 0.6616 - val_accuracy: 0.8048
# Epoch 38/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4780 - accuracy: 0.8572 - val_loss: 0.6523 - val_accuracy: 0.8048
# Epoch 39/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.5197 - accuracy: 0.8520 - val_loss: 0.9172 - val_accuracy: 0.7520
# Epoch 40/40
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4598 - accuracy: 0.8560 - val_loss: 0.6348 - val_accuracy: 0.8112
#
#
# ********    5번 러닝 완료    *********

# %%
prediction=0
folds=5
repeats=5
epochsize=40
drop=0.5
kfold = KFold(n_splits=folds, shuffle=True)

for k in range(repeats):
    for train_ind, test_ind in kfold.split(X, y):
        model = Sequential()
        model.add(Conv1D (kernel_size=60, filters=256, strides=3, padding='valid',
                        kernel_initializer='he_uniform', input_shape=X.shape[1:],
                        activation='relu'))
        model.add(MaxPooling1D(1, padding = 'valid'))

        model.add(Conv1D(kernel_size=60, filters=128, activation='relu'))
        model.add(MaxPooling1D(1, padding = 'valid'))

        model.add(Conv1D(kernel_size=60, filters=64, activation='relu'))
        model.add(MaxPooling1D(1, padding = 'valid'))

        model.add(BatchNormalization())

        model.add(Dropout(drop))
        model.add(Flatten())
        model.add(Dense(1024, activation='relu'))
        model.add(BatchNormalization())

        model.add(Dropout(drop))
        model.add(Dense(1024, activation='relu'))
        model.add(BatchNormalization())

        model.add(Dropout(drop))
        model.add(Dense(1024, activation='relu'))
        model.add(BatchNormalization())


        model.add(Dropout(drop))
        model.add(Dense(61))
        model.add(Activation('softmax'))

        adam = optimizers.Adam(lr=0.0001)

        model.compile(loss='categorical_crossentropy',
                      optimizer=adam,
                      metrics=['accuracy'])

        model.fit(np.array(X)[train_ind], y[train_ind], epochs=epochsize, batch_size=64,
                  validation_data=(np.array(X)[test_ind], y[test_ind]))

        prediction += (model.predict(test_x)/(folds*repeats))
    
    print(f'********    {k}번 러닝 완료    *********')
submission.iloc[:,1:]=prediction
submission.to_csv('py_answer2.csv', index=False)

# %%
prediction=0
folds=5
repeats=5
epochsize=40
drop=0.5
kfold = KFold(n_splits=folds, shuffle=True)
es =EarlyStopping(monitor='val_loss', patience=10, mode='min')

for k in range(repeats):
    for train_ind, test_ind in kfold.split(X, y):
        model = Sequential()
        model.add(Conv1D (kernel_size=30, filters=256, strides=3, padding='valid',
                         kernel_initializer='he_uniform', input_shape=X.shape[1:],
                         activation='relu'))
        model.add(MaxPooling1D(1, padding = 'valid'))

        model.add(Conv1D(kernel_size=30, filters=128, activation='relu'))
        model.add(MaxPooling1D(1, padding = 'valid'))

        model.add(BatchNormalization())

        model.add(Dropout(drop))
        model.add(GlobalAveragePooling1D())
        model.add(Dense(512, activation='relu'))
        model.add(BatchNormalization())

        model.add(Dropout(drop))
        model.add(Dense(61))
        model.add(Activation('softmax'))

        adam = optimizers.Adam(lr=0.0001)

        model.compile(loss='categorical_crossentropy',
                      optimizer=adam,
                      metrics=['accuracy'])

        model.fit(np.array(X)[train_ind], y[train_ind], epochs=epochsize, batch_size=64,
                  validation_data=(np.array(X)[test_ind], y[test_ind]), callbacks = [es])

        prediction += (model.predict(test_x)/(folds*repeats))
    print(f'\n\n********    {k+1}번 러닝 완료    *********\n\n')
submission.iloc[:,1:]=prediction
submission.to_csv('py_answer3.csv', index=False)

# %% [markdown]
# ##### 성능 확인 및 제출

# %%
model1ans=pd.read_csv('./py_answer1.csv')
model2ans=pd.read_csv('./py_answer2.csv')
model3ans=pd.read_csv('./py_answer3.csv')

# %%
final_sv=(model1ans+model2ans+model3ans)/3

# %%
# final_sv.to_csv('/content/drive/MyDrive/월간데이콘11/py_new4.csv', index=False)

final_sv.to_csv('py_final_answer.csv', index=False)
