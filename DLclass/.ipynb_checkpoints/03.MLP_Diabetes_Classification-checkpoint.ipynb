# %% [markdown]
# ### 딥-러닝 과정 Mulit Layer Perceptron(MLP)

# %% [markdown]
# ## Keras 모델 생성/학습 - 당뇨병 예측 모델

# %%
# 1. Pandas 가져오기
import pandas as pd

print(pd.__version__)
# Out:
# 1.2.4

# %%
# 2. 데이터 불러오기
df = pd.read_csv('../DLclass/diabetes_data.csv')
df
# Out:
#      pregnant  gloucose  blood pressure  skin thickness  insulin   BMI    DPF  \
# 0           6       148              72              35        0  33.6  0.627
# 1           1        85              66              29        0  26.6  0.351
# 2           8       183              64               0        0  23.3  0.672
# 3           1        89              66              23       94  28.1  0.167
# 4           0       137              40              35      168  43.1  2.288
# ..        ...       ...             ...             ...      ...   ...    ...
# 763        10       101              76              48      180  32.9  0.171
# 764         2       122              70              27        0  36.8  0.340
# 765         5       121              72              23      112  26.2  0.245
# 766         1       126              60               0        0  30.1  0.349
# 767         1        93              70              31        0  30.4  0.315
#
#      age  result
# 0     50       1
# 1     31       0
# 2     32       1
# 3     21       0
# 4     33       1
# ..   ...     ...
# 763   63       0
# 764   27       0
# 765   30       0
# 766   47       1
# 767   23       0
#
# [768 rows x 9 columns]

# %%
df.describe()
# Out:
#          pregnant    gloucose  blood pressure  skin thickness     insulin  \
# count  768.000000  768.000000      768.000000      768.000000  768.000000
# mean     3.845052  120.894531       69.105469       20.536458   79.799479
# std      3.369578   31.972618       19.355807       15.952218  115.244002
# min      0.000000    0.000000        0.000000        0.000000    0.000000
# 25%      1.000000   99.000000       62.000000        0.000000    0.000000
# 50%      3.000000  117.000000       72.000000       23.000000   30.500000
# 75%      6.000000  140.250000       80.000000       32.000000  127.250000
# max     17.000000  199.000000      122.000000       99.000000  846.000000
#
#               BMI         DPF         age      result
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# 50%     32.000000    0.372500   29.000000    0.000000
# 75%     36.600000    0.626250   41.000000    1.000000
# max     67.100000    2.420000   81.000000    1.000000

# %%
# 8. Feature Heatmap 시각화
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# feature heatmap 그려보기
dfcorr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(dfcorr, cmap='viridis')
#sns.heatmap(df_17corr, annot=True, fmt='f')
plt.title('Heatmap of dforr by seaborn', fontsize=15)

plt.show()

# %%
# 3. X/y 나누기
x = df.iloc[:,:8]
y = df.iloc[:,8:]

# %%
x
# Out:
#      pregnant  gloucose  blood pressure  skin thickness  insulin   BMI    DPF  \
# 0           6       148              72              35        0  33.6  0.627
# 1           1        85              66              29        0  26.6  0.351
# 2           8       183              64               0        0  23.3  0.672
# 3           1        89              66              23       94  28.1  0.167
# 4           0       137              40              35      168  43.1  2.288
# ..        ...       ...             ...             ...      ...   ...    ...
# 763        10       101              76              48      180  32.9  0.171
# 764         2       122              70              27        0  36.8  0.340
# 765         5       121              72              23      112  26.2  0.245
# 766         1       126              60               0        0  30.1  0.349
# 767         1        93              70              31        0  30.4  0.315
#
#      age
# 0     50
# 1     31
# 2     32
# 3     21
# 4     33
# ..   ...
# 763   63
# 764   27
# 765   30
# 766   47
# 767   23
#
# [768 rows x 8 columns]

# %%
y
# Out:
#      result
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# ..      ...
# 763       0
# 764       0
# 765       0
# 766       1
# 767       0
#
# [768 rows x 1 columns]

# %%
# 4. Train set, Test set 나누기
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=123)

x_val, x_test, y_val, y_test = train_test_split(x_test,y_test,test_size=0.5,random_state=100)

# %%
# 5. Keras 패키지 가져오기
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout

# %%
# 6. MLP 모델 생성
model = keras.Sequential()

model.add(layers.Dense(input_dim=x_train.shape[1], units=128, activation='relu'))
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=32, activation='relu',
                      kernel_regularizer=keras.regularizers.L2(0.1)))

#model.add(layers.Dropout(0.2))

model.add(layers.Dense(units=16, activation='relu'))
model.add(layers.Dense(units=8, activation='relu'))
model.add(layers.Dense(units=1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_248 (Dense)            (None, 128)               1152
# _________________________________________________________________
# dense_249 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_250 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_251 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_252 (Dense)            (None, 8)                 136
# _________________________________________________________________
# dense_253 (Dense)            (None, 1)                 9
# =================================================================
# Total params: 12,161
# Trainable params: 12,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 7. Compile - Optimizer, Loss function 설정
#sgd = keras.optimizers.SGD(lr=0.1, momentum=0.5)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

# 빠른 종료
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# 8. 학습시키기
hist = model.fit(x_train,y_train,validation_data=(x_val, y_val), batch_size=4,epochs=150,verbose=1,callbacks=[early_stopping])
# Out:
# Epoch 1/150
# 154/154 [==============================] - 1s 2ms/step - loss: 3.7816 - accuracy: 0.6091 - val_loss: 2.7786 - val_accuracy: 0.5974
# Epoch 2/150
# 154/154 [==============================] - 0s 1ms/step - loss: 2.2753 - accuracy: 0.6336 - val_loss: 1.9518 - val_accuracy: 0.6364
# Epoch 3/150
# 154/154 [==============================] - 0s 1ms/step - loss: 1.7195 - accuracy: 0.6580 - val_loss: 1.5330 - val_accuracy: 0.6364
# Epoch 4/150
# 154/154 [==============================] - 0s 1ms/step - loss: 1.3885 - accuracy: 0.6661 - val_loss: 1.2457 - val_accuracy: 0.6623
# Epoch 5/150
# 154/154 [==============================] - 0s 1ms/step - loss: 1.1685 - accuracy: 0.6710 - val_loss: 1.0610 - val_accuracy: 0.7273
# Epoch 6/150
# 154/154 [==============================] - 0s 1ms/step - loss: 1.0044 - accuracy: 0.6629 - val_loss: 0.9158 - val_accuracy: 0.6364
# Epoch 7/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.8787 - accuracy: 0.6938 - val_loss: 0.9234 - val_accuracy: 0.6364
# Epoch 8/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.8010 - accuracy: 0.6580 - val_loss: 0.7388 - val_accuracy: 0.6623
# Epoch 9/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.7485 - accuracy: 0.6743 - val_loss: 0.6995 - val_accuracy: 0.6364
# Epoch 10/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.7029 - accuracy: 0.6873 - val_loss: 0.6519 - val_accuracy: 0.6753
# Epoch 11/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6715 - accuracy: 0.6873 - val_loss: 0.6202 - val_accuracy: 0.6753
# Epoch 12/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6553 - accuracy: 0.6678 - val_loss: 0.6108 - val_accuracy: 0.7792
# Epoch 13/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6378 - accuracy: 0.6759 - val_loss: 0.6025 - val_accuracy: 0.7273
# Epoch 14/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6215 - accuracy: 0.7117 - val_loss: 0.5895 - val_accuracy: 0.7013
# Epoch 15/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6199 - accuracy: 0.6922 - val_loss: 0.5880 - val_accuracy: 0.7273
# Epoch 16/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6376 - accuracy: 0.6694 - val_loss: 0.6071 - val_accuracy: 0.7532
# Epoch 17/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6353 - accuracy: 0.6840 - val_loss: 0.6182 - val_accuracy: 0.7532
# Epoch 18/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6215 - accuracy: 0.6987 - val_loss: 0.5895 - val_accuracy: 0.7792
# Epoch 19/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6063 - accuracy: 0.6857 - val_loss: 0.5872 - val_accuracy: 0.7922
# Epoch 20/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6032 - accuracy: 0.7020 - val_loss: 0.5667 - val_accuracy: 0.8052
# Epoch 21/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5990 - accuracy: 0.6775 - val_loss: 0.5668 - val_accuracy: 0.8182
# Epoch 22/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.6004 - accuracy: 0.6906 - val_loss: 0.5565 - val_accuracy: 0.7013
# Epoch 23/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5989 - accuracy: 0.6954 - val_loss: 0.5648 - val_accuracy: 0.7792
# Epoch 24/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5981 - accuracy: 0.6873 - val_loss: 0.5793 - val_accuracy: 0.7273
# Epoch 25/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.6889 - val_loss: 0.5836 - val_accuracy: 0.6753
# Epoch 26/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.6971 - val_loss: 0.5564 - val_accuracy: 0.8052
# Epoch 27/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5922 - accuracy: 0.7036 - val_loss: 0.5295 - val_accuracy: 0.7532
# Epoch 28/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5768 - accuracy: 0.7117 - val_loss: 0.5376 - val_accuracy: 0.7922
# Epoch 29/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5745 - accuracy: 0.7248 - val_loss: 0.5456 - val_accuracy: 0.7532
# Epoch 30/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5706 - accuracy: 0.7150 - val_loss: 0.5124 - val_accuracy: 0.7792
# Epoch 31/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5722 - accuracy: 0.7166 - val_loss: 0.5380 - val_accuracy: 0.7532
# Epoch 32/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5760 - accuracy: 0.7052 - val_loss: 0.5320 - val_accuracy: 0.7662
# Epoch 33/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5695 - accuracy: 0.7020 - val_loss: 0.5351 - val_accuracy: 0.7922
# Epoch 34/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5625 - accuracy: 0.7150 - val_loss: 0.5576 - val_accuracy: 0.7792
# Epoch 35/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7345 - val_loss: 0.5256 - val_accuracy: 0.7532
# Epoch 36/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5447 - accuracy: 0.7427 - val_loss: 0.5244 - val_accuracy: 0.7662
# Epoch 37/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5382 - accuracy: 0.7345 - val_loss: 0.5455 - val_accuracy: 0.7922
# Epoch 38/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5437 - accuracy: 0.7443 - val_loss: 0.5292 - val_accuracy: 0.7662
# Epoch 39/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5293 - accuracy: 0.7264 - val_loss: 0.5565 - val_accuracy: 0.7792
# Epoch 40/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5378 - accuracy: 0.7378 - val_loss: 0.5017 - val_accuracy: 0.7922
# Epoch 41/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5317 - accuracy: 0.7362 - val_loss: 0.5335 - val_accuracy: 0.7403
# Epoch 42/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5225 - accuracy: 0.7427 - val_loss: 0.5311 - val_accuracy: 0.7792
# Epoch 43/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5157 - accuracy: 0.7573 - val_loss: 0.5171 - val_accuracy: 0.7532
# Epoch 44/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5147 - accuracy: 0.7492 - val_loss: 0.6023 - val_accuracy: 0.7143
# Epoch 45/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5229 - accuracy: 0.7590 - val_loss: 0.5642 - val_accuracy: 0.7403
# Epoch 46/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5210 - accuracy: 0.7394 - val_loss: 0.5216 - val_accuracy: 0.7792
# Epoch 47/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5224 - accuracy: 0.7329 - val_loss: 0.5221 - val_accuracy: 0.7922
# Epoch 48/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5061 - accuracy: 0.7573 - val_loss: 0.5555 - val_accuracy: 0.7662
# Epoch 49/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5108 - accuracy: 0.7508 - val_loss: 0.5271 - val_accuracy: 0.7792
# Epoch 50/150
# 154/154 [==============================] - 0s 1ms/step - loss: 0.5056 - accuracy: 0.7590 - val_loss: 0.5708 - val_accuracy: 0.7403

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['train', 'val'], loc='upper left')


plt.show()

# %%
# 9. 모델 평가하기
from sklearn.metrics import classification_report
model.evaluate(x_train, y_train)
model.evaluate(x_test, y_test)
# Out:
# 20/20 [==============================] - 0s 670us/step - loss: 0.4865 - accuracy: 0.7590
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5492 - accuracy: 0.7143
# [0.5491960048675537, 0.7142857313156128]

# %%
# 10. 학습 시각화하기
